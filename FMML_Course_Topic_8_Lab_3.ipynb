# %% [markdown]
# <a href="https://colab.research.google.com/github/Aswinimedisetti28/Fmmllabassiments/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 13:16:26--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   289MB/s    in 0.2s
#
# 2024-03-31 13:16:28 (289 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3501 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 14855   1010.2384v1  In this paper the problems of deriving a taxon...    cs
# 29033  1708.02721v2  In this paper, we present a deep learning base...    cs
# 22174  1506.05843v1  Many practical modeling problems involve discr...  stat
# 5968    1401.8008v2  In ranking problems, the goal is to learn a ra...  stat
# 28388  1706.04306v1  Style transfer methods have achieved significa...    cs
# ...             ...                                                ...   ...
# 22222  1508.07535v1  A general approach for anomaly detection or no...  stat
# 2609   1610.09296v3  We focus on generative autoencoders, such as v...    cs
# 19272   1304.2754v1  A method for computing probabilistic propositi...    cs
# 8448   1608.08710v3  The success of CNNs in various applications is...    cs
# 22311  1512.08643v2  Functional brain networks are well described a...  stat
#
#                                                    title  year  \
# 14855  Learning Taxonomy for Text Segmentation by For...  2010
# 29033               Deep Face Feature for Face Alignment  2017
# 22174  Dependent Multinomial Models Made Easy: Stick ...  2015
# 5968                  Support vector comparison machines  2014
# 28388            Photo-realistic Facial Texture Transfer  2017
# ...                                                  ...   ...
# 22222  Calibration of One-Class SVM for MV set estima...  2015
# 2609   Improving Sampling from Generative Autoencoder...  2016
# 19272  An Algorithm for Computing Probabilistic Propo...  2013
# 8448              Pruning Filters for Efficient ConvNets  2016
# 22311  Testing for Differences in Gaussian Graphical ...  2015
#
#                                                 keywords
# 14855  [segmentation, approached, linguistic, segment...
# 29033  [extraction, specifically, extraction, constru...
# 22174  [practical, represented, multinomial, categori...
# 5968   [comparison, indicates, significant, differenc...
# 28388  [significant, convolutional, concentrate, cons...
# ...                                                  ...
# 22222  [detection, detection, estimating, algorithm, ...
# 2609   [generative, autoencoders, variational, advers...
# 19272  [computing, probabilistic, propositions, prese...
# 8448   [applications, accompanied, significant, compu...
# 22311  [functional, described, estimated, graphical, ...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 14855    [segmentation, approached, linguistic, segment...
# 29033    [extraction, specifically, extraction, constru...
# 22174    [practical, represented, multinomial, categori...
# 5968     [comparison, indicates, significant, differenc...
# 28388    [significant, convolutional, concentrate, cons...
#                                ...
# 18631    [adjustable, dynamically, transferring, transf...
# 9871     [algorithm, hierarchical, clustering, effectiv...
# 22701    [emergence, development, accumulated, processe...
# 34023    [essential, verification, technique, identifyi...
# 12804    [supervision, positions, velocities, dimension...
# Name: keywords, Length: 6001, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8665 words.
# Out of those 4524 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a1b217b4-6392-451f-ab8d-ec80314cba30" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1b217b4-6392-451f-ab8d-ec80314cba30")) {                    Plotly.newPlot(                        "a1b217b4-6392-451f-ab8d-ec80314cba30",                        [{"x":["segmentation","sentences","clustering","presented","approached","experimental","linguistic","conceptual","algorithm","iteratively","demonstrate","extensive","experiments","procedure","realistic","unconstrained","descriptors","distinguishes","alignment","specifically","effective","synthesized","rendering","construct","photographs","extraction","landmarks","correspondence","different","representation","innovations","likelihoods","childrens","inference","reformulate","preceding","represented","augmentation","correlated","naturally","formulation","nucleotide","advantage","multinomial","dependencies","dependent","categorical","variables","techniques","practical","distributions","documents","distribution","dirichlet","dependency","difference","indicates","simulated","significant","outperforms","maximization","nonlinear","converting","comparison","framework","concentrate","convolutional","transferred","suppressing","structures","transferring","structure","photorealistic","appearance","preserves","incorporates","challenging","implicitly","constraints","regularization","automatic","annotation","supervised","indispensable","sparseness","unsupervised","effectiveness","formalize","generalizing","derivation","beneficial","technology","multivariate","reliability","classification","properties","regression","promising","bootstrap","intractable","evaluating","solutions","encounter","evaluates","transforms","integrals","simplicity","improvements","evaluated","recursively","evolutionary","posterior","continuous","completely","optimization","addressed","algorithms","strategies","published","innovation","estimating","previously","represent","similarities","univariate","highlight","respective","scenarios","information","parameters","nonstationary","frequently","classical","filtering","approximated","cancellation","efficient","generalization","illustrate","instantaneous","likelihood","identification","selection","advancements","particles","achievements","calculated","realizations","successfully","recommendation","increased","sequential","inferential","advertising","developments","encompasses","approaches","combining","hierarchical","additionally","generality","empirical","contextual","outperform","simulation","efficiency","exploring","reasoning","occlusion","conditions","geometric","egocentric","popularity","surveillance","community","viewpoints","drastically","literature","demonstrates","identities","divergence","categorization","introduce","discriminative","hypothesis","classifiers","important","classifier","asymptotic","automated","discrimination","biologically","plausible","permutation","independently","propagated","principle","connections","reciprocal","artificial"],"y":[201,72,159,187,5,371,70,19,843,26,572,176,643,119,80,24,45,7,54,176,260,12,16,80,8,161,12,26,745,346,5,4,1,230,3,5,70,26,40,60,89,2,105,3,56,69,19,132,384,116,120,80,191,18,42,56,23,61,253,254,39,58,5,139,582,11,364,13,3,124,20,334,3,76,18,46,261,19,148,78,180,52,214,8,5,179,204,14,18,8,22,60,18,19,516,196,113,119,3,27,59,155,3,11,13,3,27,122,143,7,66,45,106,40,299,45,629,107,45,6,64,106,129,43,5,30,24,90,700,226,1,31,114,59,19,0,399,108,63,4,73,111,176,4,6,2,30,1,93,28,40,69,4,8,17,3,404,91,111,60,16,161,45,112,83,148,40,130,24,133,68,7,23,37,72,13,13,130,61,9,29,17,319,115,41,103,336,146,17,92,20,15,27,3,32,7,55,51,2,131],"type":"bar"},{"x":["segmentation","sentences","clustering","presented","approached","experimen ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4524,), (4524, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8126561199000832

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>An</span> <span style=''>Improved</span> <span style=''>Oscillating</span> <span style=''>Error</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Classifier</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>Branching</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>extends</span> <span style=''>the</span> <span style=''>earlier</span> <span style=''>work</span> <span style=''>on</span> <span style=''>an</span> <span style=''>oscillating</span> <span style=''>error</span> <span style='background-color:rgba(0, 255, 0, 0.3157894736842105);'>correction</span> <span style='background-color:rgba(0, 255, 0, 0.3152709359605912);'>technique</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Specifically</span> <span style=''>it</span> <span style=''>extends</span> <span style=''>the</span> <span style=''>design</span> <span style=''>to</span> <span style=''>include</span> <span style=''>further</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>corrections</span> <span style=''>by</span> <span style=''>adding</span> <span style=''>new</span> <span style=''>layers</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>through</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>branching</span> <span style=''>method</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3152709359605912);'>technique</span> <span style=''>is</span> <span style=''>still</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistent</span> <span style=''>with</span> <span style=''>earlier</span> <span style=''>work</span> <span style=''>and</span> <span style=''>also</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>in</span> <span style=''>general</span> <span style=''>With</span> <span style=''>this</span> <span style=''>extended</span> <span style=''>design</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>can</span> <span style=''>now</span> <span style=''>achieve</span> <span style=''>the</span> <span style=''>high</span> <span style=''>levels</span> <span style=''>of</span> <span style=''>accuracy</span> <span style=''>reported</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>previously</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Restricted</span> <span style=''>Strong</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Convexity</span> <span style=''>Implies</span> <span style=''>Weak</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Submodularity</span> <br/><br/><span style=''>We</span> <span style=''>connect</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>subset</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>submodular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximization</span> <span style=''>Our</span> <span style=''>results</span> <span style=''>extend</span> <span style=''>the</span> <span style=''>work</span> <span style=''>of</span> <span style=''>Das</span> <span style=''>and</span> <span style=''>Kempe</span> <span style=''>(2011)</span> <span style=''>from</span> <span style=''>the</span> <span style=''>setting</span> <span style=''>of</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>arbitrary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>For</span> <span style=''>greedy</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>connection</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>obtain</span> <span style=''>strong</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multiplicative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>several</span> <span style=''>methods</span> <span style=''>without</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>modeling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>We</span> <span style=''>also</span> <span style=''>derive</span> <span style=''>recovery</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guarantees</span> <span style=''>of</span> <span style=''>this</span> <span style=''>form</span> <span style=''>under</span> <span style=''>standard</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>Our</span> <span style=''>work</span> <span style=''>shows</span> <span style=''>that</span> <span style=''>greedy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>perform</span> <span style=''>within</span> <span style=''>a</span> <span style=''>constant</span> <span style=''>factor</span> <span style=''>from</span> <span style=''>the</span> <span style=''>best</span> <span style=''>possible</span> <span style=''>subset</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>solution</span> <span style=''>for</span> <span style=''>a</span> <span style=''>broad</span> <span style=''>class</span> <span style=''>of</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>Our</span> <span style=''>methods</span> <span style=''>allow</span> <span style=''>a</span> <span style=''>direct</span> <span style=''>control</span> <span style=''>over</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>obtained</span> <span style=''>features</span> <span style=''>as</span> <span style=''>opposed</span> <span style=''>to< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>the</span> <span style=''>Finite</span> <span style=''>Time</span> <span style='background-color:rgba(255, 0, 0, 0.3010752688172042);'>Convergence</span> <span style=''>of</span> <span style=''>Cyclic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Coordinate</span> <span style=''>Descent</span> <span style=''>Methods</span> <br/><br/><span style=''>Cyclic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coordinate</span> <span style=''>descent</span> <span style=''>is</span> <span style=''>a</span> <span style=''>classic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>method</span> <span style=''>that</span> <span style=''>has</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>witnessed</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resurgence</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>Reasons</span> <span style=''>for</span> <span style=''>this</span> <span style=''>include</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simplicity</span> <span style=''>speed</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>stability</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>competitive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>on</span> <span style=''>ell</span> <span style=''>1</span> <span style='background-color:rgba(255, 0, 0, 0.42635658914728675);'>regularized</span> <span style=''>smooth</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problems</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Surprisingly</span> <span style=''>very</span> <span style=''>little</span> <span style=''>is</span> <span style=''>known</span> <span style=''>about</span> <span style=''>its</span> <span style=''>finite</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3010752688172042);'>convergence</span> <span style=''>behavior</span> <span style=''>on</span> <span style=''>these</span> <span style=''>problems</span> <span style=''>Most</span> <span style=''>existing</span> <span style=''>results</span> <span style=''>either</span> <span style=''>just</span> <span style=''>prove</span> <span style='background-color:rgba(255, 0, 0, 0.3010752688172042);'>convergence</span> <span style=''>or</span> <span style=''>provide</span> <span style='background-color:rgba(255, 0, 0, 0.6822429906542055);'>asymptotic</span> <span style=''>rates</span> <span style=''>We</span> <span style=''>fill</span> <span style=''>this</span> <span style=''>gap</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style=''>by</span> <span style=''>proving</span> <span style=''>O(1k)</span> <span style='background-color:rgba(255, 0, 0, 0.3010752688172042);'>convergence</span> <span style=''>rates</span> <span style=''>(where</span> <span style=''>k</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteration</span> <span style=''>counter)</span> <span style=''>for</span> <span style=''>two</span> <span style=''>variants</span> <span style=''>of</span> <span style=''>cyclic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coordinate</span> <span style=''>descent</span> <span style=''>under</span> <span style=''>an</span> <span style=''>isotonicity</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumption</span> <span style=''>Our</span> <span style=''>analysis</span> <span style=''>proceeds</span> <span style=''>by</span> <s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>An</span> <span style=''>optimal</span> <span style=''>learning</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>personalized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style=''>regimes</span> <br/><br/><span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style=''>regime</span> <span style=''>is</span> <span style=''>a</span> <span style=''>function</span> <span style=''>that</span> <span style=''>maps</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style=''>patient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recommended</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style=''>hence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explicitly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporating</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heterogeneity</span> <span style=''>in</span> <span style=''>need</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style=''>across</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individuals</span> <span style=''>Patient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>responses</span> <span style=''>are</span> <span style=''>dichotomous</span> <span style=''>and</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predicted</span> <span style=''>through</span> <span style=''>an</span> <span style=''>unknown</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationship</span> <span style=''>that</span> <span style=''>depends</span> <span style=''>on</span> <span style=''>the</span> <span style=''>patient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>and</span> <span style=''>the</span> <span style=''>selected</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style=''>The</span> <span style=''>goal</span> <span style=''>is</span> <span style=''>to</span> <span style=''>find</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatments</span> <span style=''>that</span> <span style=''>lead</span> <span style=''>to</span> <span style=''>the</span> <span style=''>best</span> <span style=''>patient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>responses</span> <span style=''>on</span> <span style=''>average</span> <span style=''>Each</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiment</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expensive</span> <span style=''>forcing</span> <span style=''>us</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>the</span> <span style=''>most</span> <span style=''>from</span> <span style=''>each</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiment</span> <span style=''>We</span> <span style=''>adopt</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style=''>approach</span> <span style=''>both</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporate</span> <span style=''>possible</span> <span style=''>prior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>and</span> <span style=''>to</span> <span style=''>update</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style=''>regime</span> <span style='background-color:rgba(255, 0, ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13297491039426523)
# 	architecture (0.08817204301075268)
# 	segmentation (0.07204301075268817)
# 	processing (0.10896057347670252)
# 	knowledge (0.12759856630824373)
# 	detection (0.11505376344086021)
# 	information (0.25089605734767023)
# 	different (0.2670250896057348)
# 	convolutional (0.13046594982078852)
# 	recognition (0.14587813620071685)
#
# Some Statistics words are:
# 	algorithm (0.3965174129353234)
# 	stochastic (0.14129353233830846)
# 	variables (0.14626865671641792)
# 	statistical (0.1626865671641791)
# 	estimation (0.17412935323383086)
# 	theoretical (0.15870646766169155)
# 	inference (0.1900497512437811)
# 	distribution (0.1855721393034826)
# 	dimensional (0.19054726368159203)
# 	regression (0.1781094527363184)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2e67ae56-519c-4509-aed5-6e177d9a7734" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e67ae56-519c-4509-aed5-6e177d9a7734")) {                    Plotly.newPlot(                        "2e67ae56-519c-4509-aed5-6e177d9a7734",                        [{"x":["segmentation","sentences","clustering","presented","approached","experimental","linguistic","conceptual","algorithm","iteratively","demonstrate","extensive","experiments","procedure","realistic","unconstrained","descriptors","distinguishes","alignment","specifically","effective","synthesized","rendering","construct","photographs","extraction","landmarks","correspondence","different","representation","innovations","likelihoods","childrens","inference","reformulate","preceding","represented","augmentation","correlated","naturally","formulation","nucleotide","advantage","multinomial","dependencies","dependent","categorical","variables","techniques","practical","distributions","documents","distribution","dirichlet","dependency","difference","indicates","simulated","significant","outperforms","maximization","nonlinear","converting","comparison","framework","concentrate","convolutional","transferred","suppressing","structures","transferring","structure","photorealistic","appearance","preserves","incorporates","challenging","implicitly","constraints","regularization","automatic","annotation","supervised","indispensable","sparseness","unsupervised","effectiveness","formalize","generalizing","derivation","beneficial","technology","multivariate","reliability","classification","properties","regression","promising","bootstrap","intractable","evaluating","solutions","encounter","evaluates","transforms","integrals","simplicity","improvements","evaluated","recursively","evolutionary","posterior","continuous","completely","optimization","addressed","algorithms","strategies","published","innovation","estimating","previously","represent","similarities","univariate","highlight","respective","scenarios","information","parameters","nonstationary","frequently","classical","filtering","approximated","cancellation","efficient","generalization","illustrate","instantaneous","likelihood","identification","selection","advancements","particles","achievements","calculated","realizations","successfully","recommendation","increased","sequential","inferential","advertising","developments","encompasses","approaches","combining","hierarchical","additionally","generality","empirical","contextual","outperform","simulation","efficiency","exploring","reasoning","occlusion","conditions","geometric","egocentric","popularity","surveillance","community","viewpoints","drastically","literature","demonstrates","identities","divergence","categorization","introduce","discriminative","hypothesis","classifiers","important","classifier","asymptotic","automated","discrimination","biologically","plausible","permutation","independently","propagated","principle","connections","reciprocal","artificial","condition","propagating","propagation","invariant","connected","discovered","performance","activation","symmetric","statistical","improving","interpretation","applicability","conditional","functions","succeeded","piecewise","probabilities","continuum","simultaneous","probability","individually","accelerating","component","additional","advantages","especially","versatile","similarly","discontinuous","functional","interesting","laboratory","informational","classified","semantics","projections","evaluation","positioning","syntactic","computational","constituency","probabilistic","psycholinguistic","linguistics","pragmatic","twentieth","displaced","complexity","rhetorical","variations","including","variation","recognition","be ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	cancellation
# 	continuum
# 	purchasing
# 	individualized
# 	discretised
# 	prominence
# 	pretreatment
# 	irregularly
# 	stragglers
# 	straggler
# 	activating
# 	heteroskedastic
# 	discretizations
# 	explodingvanishing
# 	semiparametric
# 	quantiles
# 	climatology
# 	popularized
# 	prejudice
# 	determinantal
# Some words which never appear in Statistics papers:
# 	photographs
# 	suppressing
# 	identities
# 	constituency
# 	psycholinguistic
# 	twentieth
# 	displaced
# 	rhetorical
# 	spiegelhalter
# 	argumentation
# 	rationale
# 	discounting
# 	consequential
# 	transcripts
# 	recurrence
# 	committee
# 	centrality
# 	strengthens
# 	compatibility
# 	orderings

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.08413520848754e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7743547044129891
